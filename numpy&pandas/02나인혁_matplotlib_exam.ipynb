# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.0, 5.0, 6)
x
# Out:
# array([0., 1., 2., 3., 4., 5.])

# %%
x = np.linspace(0,5,6)
y_n = 2 ** x
y_nlogn = x * y_n
y_n2 = y_n ** 2
y_n3 = y_n ** 3
y_2n = 2 ** y_n
print(x)
print(y_n)
print(y_nlogn)
print(y_n2)
print(y_n3)
print(y_2n)
# Out:
# [0. 1. 2. 3. 4. 5.]
# [ 1.  2.  4.  8. 16. 32.]
# [  0.   2.   8.  24.  64. 160.]
# [1.000e+00 4.000e+00 1.600e+01 6.400e+01 2.560e+02 1.024e+03]
# [1.0000e+00 8.0000e+00 6.4000e+01 5.1200e+02 4.0960e+03 3.2768e+04]
# [2.0000000e+00 4.0000000e+00 1.6000000e+01 2.5600000e+02 6.5536000e+04
#  4.2949673e+09]

# %%
plt.plot(x, y_n)
plt.show()

# %%
plt.plot(x, y_nlogn)
plt.show()

# %%
plt.plot(x, y_n2)
plt.show()

# %%
plt.plot(x, y_n3)
plt.show()

# %%
plt.plot(x, y_2n)
plt.show()

# %%
plt.subplot(2,3,1)
plt.plot(x, y_n)

plt.subplot(2,3,2)
plt.plot(x, y_nlogn)

plt.subplot(2,3,3)
plt.plot(x, y_n2)

plt.subplot(2,3,4)
plt.plot(x, y_n3)

plt.subplot(2,3,5)
plt.plot(x, y_2n)

plt.show()

# %%
plt.subplot(2,3,1)
plt.plot(x, y_n, color = 'red', linewidth = 1, alpha = 0.7,
       linestyle = '--', marker = 'o', markersize = 5,
       markerfacecolor = 'violet', markeredgewidth = 3, markeredgecolor = 'hotpink')

plt.subplot(2,3,2)
plt.plot(x, y_nlogn, color = 'green', linewidth = 1, alpha = 0.7,
       linestyle = '--', marker = '*', markersize = 5,
       markerfacecolor = 'green', markeredgewidth = 3, markeredgecolor = 'green')

plt.subplot(2,3,3)
plt.plot(x, y_n2, color = 'blue', linewidth = 1, alpha = 0.7,
       linestyle = '--', marker = 's', markersize = 5,
       markerfacecolor = 'skyblue', markeredgewidth = 3, markeredgecolor = 'skyblue')

plt.subplot(2,3,4)
plt.plot(x, y_n3,  color = 'brown', linewidth = 1, alpha = 0.7,
       linestyle = '--', marker = '^', markersize = 5,
       markerfacecolor = 'brown', markeredgewidth = 3, markeredgecolor = 'brown')

plt.subplot(2,3,5)
plt.plot(x, y_2n, color = 'black', linewidth = 1, alpha = 0.7,
       linestyle = '--', marker = 'h', markersize = 5,
       markerfacecolor = 'gray', markeredgewidth = 3, markeredgecolor = 'gray')

plt.show()
